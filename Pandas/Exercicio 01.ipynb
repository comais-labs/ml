# %% [markdown]
# ## Exercício 01
# O conjunto de dados utilizado para este exercício é o de Arrecadação por Estado, disponibilizado pelo Ministério da Fazenda no Portal de Dados Abertos do Governo Federal.
#
# Para carregá-lo, utilize o link abaixo:
# https://gist.githubusercontent.com/rogernogueira/926c7e0b599908685f7303371d13f9dc/raw/8282729458b64ce59ebf7c21127ac181bb7a4053/arrecadacao-estados.csv
#
# DICA: para facilitar a compreensão dos resultados, converta os valores da tabela para o formato float com duas casas após a vírgula, através da seguinte linha de código:
# `pd.optitons.display.float_format = '{:.2f}'.format`

# %%
import pandas as pd

# %%
url = "https://gist.githubusercontent.com/rogernogueira/926c7e0b599908685f7303371d13f9dc/raw/8282729458b64ce59ebf7c21127ac181bb7a4053/arrecadacao-estados.csv"
df = pd.read_csv(url)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Ano', 'Mês', 'UF', 'IMPOSTO SOBRE IMPORTAÇÃO',
#        'IMPOSTO SOBRE EXPORTAÇÃO', 'IPI - FUMO', 'IPI - BEBIDAS',
#        'IPI - AUTOMÓVEIS', 'IPI - VINCULADO À IMPORTACAO', 'IPI - OUTROS',
#        'IRPF', 'IRPJ - ENTIDADES FINANCEIRAS', 'IRPJ - DEMAIS EMPRESAS',
#        'IRRF - RENDIMENTOS DO TRABALHO', 'IRRF - RENDIMENTOS DO CAPITAL',
#        'IRRF - REMESSAS P/ EXTERIOR', 'IRRF - OUTROS RENDIMENTOS',
#        'IMPOSTO S/ OPERAÇÕES FINANCEIRAS', 'IMPOSTO TERRITORIAL RURAL',
#        'COFINS - FINANCEIRAS', 'COFINS - DEMAIS',
#        'CONTRIBUIÇÃO PARA O PIS/PASEP - FINANCEIRAS',
#        'CONTRIBUIÇÃO PARA O PIS/PASEP - DEMAIS', 'CSLL - FINANCEIRAS',
#        'CSLL - DEMAIS', 'CIDE-COMBUSTÍVEIS',
#        'CPSSS - Contrib. p/ o Plano de Segurid. Social Serv. Público',
#        'OUTRAS RECEITAS ADMINISTRADAS', 'ADMINISTRADAS POR OUTROS ÓRGÃOS'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df = df.drop('Unnamed: 0', axis=1,)
# Out:
#        Ano      Mês  UF  IMPOSTO SOBRE IMPORTAÇÃO  IMPOSTO SOBRE EXPORTAÇÃO  \
# 0     2011  Janeiro  AC              2.181156e+04                     -0.03
# 1     2011  Janeiro  AL              1.064146e+05                     56.58
# 2     2011  Janeiro  AP              3.136765e+04                     -0.48
# 3     2011  Janeiro  AM              2.676490e+07                    -14.40
# 4     2011  Janeiro  BA              4.024264e+07                  24852.71
# ...    ...      ...  ..                       ...                       ...
# 4153  2023  Outubro  RR              3.616513e+04                      0.00
# 4154  2023  Outubro  SC              9.010991e+08                   7609.15
# 4155  2023  Outubro  SP              1.754629e+09                  57372.65
# 4156  2023  Outubro  SE              3.924766e+06                   -268.06
# 4157  2023  Outubro  TO              3.135981e+06                     14.65
#
#       IPI - FUMO  IPI - BEBIDAS  IPI - AUTOMÓVEIS  \
# ...

# %% [markdown]
# ### Exibir as primeiras linhas do DataFrame

# %% [markdown]
# ### Selecionando dados
# Selecionando uma coluna específica (Estado):

# %%
df[["UF","Total"]]

# %% [markdown]
# Selecionando múltiplas colunas (Estado e Total):

# %% [markdown]
# Selecionando linhas por índice usando iloc (primeiras 5 linhas):

# %% [markdown]
# Selecionando linhas por índice usando loc (linhas com índice de 0 a 4):

# %% [markdown]
# ### Filtrando dados
# Filtrando dados (Estados com arrecadação Total > 100000):

# %% [markdown]
# ### Modificando dados
# Adicionando uma nova coluna (Arrecadacao_per_capita):
# Arrecadação por população

# %% [markdown]
# ### Atualizando dados (Multiplicando a arrecadação Total por 1.1)

# %% [markdown]
# # Manipulando dados
# Ordenando o DataFrame por Total:

# %% [markdown]
# Agrupando dados por Região e somando o Total:

# %%
Salvando as modificações em um novo arquivo CSV
