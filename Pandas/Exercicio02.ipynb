# %% [markdown]
# ## Enunciado do Exercício 02: Integração de Dados
#
# Bem-vindos ao Exercício 02 do curso de Machine Learning! Neste exercício, trabalharemos com a junção de dados. Utilizaremos conjuntos de dados relacionados ao projeto qualiTOPAMA, que busca monitorar os indicadores do PQA-VS em 30 municípios situados nos estados do Tocantins, Maranhão e Pará.
#
# O projeto inclui dados de metas alcançadas nos anos de 2018, 2021 e 2022. Abaixo estão os links para os conjuntos de dados que você utilizará:
#
# - **Dados de 2018:** [Link para os dados de 2018](https://gist.githubusercontent.com/rogernogueira/cf27fa049e1433b49284c5dfdd1e4068/raw/609efc62d75743ab861318314fd581df97812432/dados_topama_2018.csv)
# - **Dados de 2021:** [Link para os dados de 2021](https://gist.githubusercontent.com/rogernogueira/cf27fa049e1433b49284c5dfdd1e4068/raw/609efc62d75743ab861318314fd581df97812432/dados_topama_2021.csv)
# - **Dados de 2022:** [Link para os dados de 2022](https://gist.githubusercontent.com/rogernogueira/cf27fa049e1433b49284c5dfdd1e4068/raw/609efc62d75743ab861318314fd581df97812432/dados_topama_2022.csv)
#
# Seu objetivo neste exercício é integrar esses conjuntos de dados e analisar as informações para identificar tendências e insights relevantes para o projeto. Boa sorte!

# %% [markdown]
# #### importe o pandas

# %% [markdown]
# Carregue um dataframe chamado `df_topama_2018` com os dados de 2018

# %% [markdown]
# Carregue um dataframe chamado `df_topama_2021` com os dados de 2021

# %% [markdown]
# Carregue um dataframe chamado `df_topama_2022` com os dados de 2022

# %% [markdown]
# Converta a coluna IBGE do df_topama_2018 para inteiro

# %% [markdown]
# Adicione o campo `ANO` no dataframe df_topama_2021

# %% [markdown]
# Deixe no dataframe df_topama_2021 somente as colunas que serão usadas(as mesmas dados dataframes anteriores)
#
# lista de indicadores
# :
# ['IND_01_ALCANCE_META',
#  'IND_02_ALCANCE_META',
#  'IND_03_ALCANCE_META',
#  'IND_04_ALCANCE_META',
#  'IND_05_ALCANCE_META',
#  'IND_06_ALCANCE_META',
#  'IND_07_ALCANCE_META',
#  'IND_08_ALCANCE_META',
#  'IND_09_ALCANCE_META',
#  'IND_10_ALCANCE_META',
#  'IND_11_ALCANCE_META',
#  'IND_12_ALCANCE_META',
#  'IND_13_ALCANCE_META',
#  'IND_14_ALCANCE_META']

# %% [markdown]
# Adicione o campo `QTD_METAS`, que deve possuir a quantidade de metas alcançadas, em cada DataFrame.

# %% [markdown]
# Concatene todos os DataFrames e nomeie o DataFrame resultante como `df_topama`.

# %% [markdown]
# Salve o df_topama em formato csv

# %% [markdown]
# Liste os três municípios com melhor desempenho em 2018

# %%
Liste os três municípios com melhor desempenho em 2022

# %% [markdown]
# Liste os três municípios com pior desempenho em 2018.

# %%
Qual estado teve a melhor média de metas alcançadas em 2018?

# %% [markdown]
# Qual estado teve a melhor média de metas alcançadas em 2022?

# %% [markdown]
# Liste os municípios que aumentaram a quantidade de metas alcançadas em comparação entre os anos de 2018 e 2021
